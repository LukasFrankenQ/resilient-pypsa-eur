# %%
import pypsa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
n = pypsa.Network(
    Path.cwd().parent / 'resources' / 'networks' / 'base_s_50__168H-T-H-B-I-A-dist1_2028_brownfield.nc'
)
# Out:
# INFO:pypsa.io:Imported network base_s_50__168H-T-H-B-I-A-dist1_2028_brownfield.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n.generators.groupby('carrier')['p_nom_extendable'].any()
# Out:
# carrier
# biogas                           False
# co2-ets                          False
# coal                              True
# gas                              False
# lignite                           True
# nuclear                          False
# offwind-ac                        True
# offwind-dc                        True
# offwind-float                     True
# oil primary                       True
# onwind                            True
# ror                              False
# rural heat vent                   True
# rural solar thermal               True
# solar                             True
# solar rooftop                    False
# solar-hsat                        True
# solid biomass                    False
# unsustainable biogas             False
# unsustainable bioliquids         False
# unsustainable solid biomass      False
# urban central heat vent           True
# urban central solar thermal       True
# urban decentral heat vent         True
# ...
